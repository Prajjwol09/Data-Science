# %%
import pandas as pd

# %%
# dataframe 

pd.DataFrame({'Yes':[50,60], 'No': [130,2]})
# Out:
#    Yes   No
# 0   50  130
# 1   60    2

# %%
pd.DataFrame({'Bob': ['I liked it','It was awful'], 'Sue': ['Pretty good.', 'Bland']},
             index = ['Product A', 'Product B'])
# Out:
#                     Bob           Sue
# Product A    I liked it  Pretty good.
# Product B  It was awful         Bland

# %%
# series 

pd.Series([1,2,3,4,5])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
pd.Series([30,40,50], index = ['2025 Sales', '2024 Sales', '2023 Sales'], name = 'Product A')
# Out:
# 2025 Sales    30
# 2024 Sales    40
# 2023 Sales    50
# Name: Product A, dtype: int64

# %%
# reading data from a file 

wine_review = pd.read_csv('winemag-data-130k-v2.csv', index_col=0)

wine_review.shape       # gives the number of rows and column of the dataset
# Out:
# (129971, 13)

# %%
wine_review.head()      # gives the first 5 row of the dataset
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %%
# creating labels

a = [1,7,2]

myvar = pd.Series(a, index= ['x','y','z'])

myvar
# Out:
# x    1
# y    7
# z    2
# dtype: int64

# %%
calories = {'day 1': 420, 'day 2': 380, 'day 3': 390, 'day 4': 400}

my_var = pd.Series(calories, index = ['day 1', 'day 2', 'day 4'])   # use of this index makes only print the columns mentioned in there.

my_var
# Out:
# day 1    420
# day 2    380
# day 4    400
# dtype: int64

# %%
# creating a simple dataframe 

data = {
    'calories': [100, 200, 300],
    'duration': [50,40,30]
}

# loading data into df 

df = pd.DataFrame(data)
df
# Out:
#    calories  duration
# 0       100        50
# 1       200        40
# 2       300        30

# %%
# locate row 

df.loc[2]       # returns the specified row
# Out:
# calories    300
# duration     30
# Name: 2, dtype: int64

# %%
# using the list of indexes 

df.loc[[0, 1, 2]]
# Out:
#    calories  duration
# 0       100        50
# 1       200        40
# 2       300        30

# %%
open_df = pd.read_csv('data.csv')

print(open_df.to_string())      # prints the entire dataframe
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
# dictionary as JSON 

json_data = {
    'Duration': {
        "0":60,
        "1":60,
        "2":60,
        "3":45,
        "4":45,
        "5":60
    },
        "Pulse":{
        "0":110,
        "1":117,
        "2":103,
        "3":109,
        "4":117,
        "5":102
    },
  "Maxpulse":{
        "0":130,
        "1":145,
        "2":135,
        "3":175,
        "4":148,
        "5":127
    },
  "Calories":{
        "0":409,
        "1":479,
        "2":340,
        "3":282,
        "4":406,
        "5":300
    }
}


json_Df = pd.DataFrame(json_data)
json_Df
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130       409
# 1        60    117       145       479
# 2        60    103       135       340
# 3        45    109       175       282
# 4        45    117       148       406
# 5        60    102       127       300

# %%
# analyzing the dataframes 

open_df.head()      # prints the first five rows
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %%
open_df.tail()      # returns the last five rows
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4

# %%
open_df.info()      # prints the info about the data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 5.4 KB

# %%
# cleaning data 

new_df = open_df.dropna()       # dropna returns the new dataframe without changing the original dataframe.

new_df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [164 rows x 4 columns]

# %%
# removing rows with null values 

open_df.dropna(inplace = True)      # removes the null values in the dataset and makes changes in the original dataset.

open_df

open_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 164 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  164 non-null    int64
#  1   Pulse     164 non-null    int64
#  2   Maxpulse  164 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 6.4 KB

# %%
# replacing empty values 

# replacing null values with number 130 

df = pd.read_csv('data.csv')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 5.4 KB

# %%
df.fillna(130, inplace = True)      # replaced the null values with 130 

df.info()       # resulted no null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  169 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 5.4 KB

# %%
# replace only for specified columns

df = pd.read_csv('data.csv')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 5.4 KB

# %%
df.fillna({'Calories': 130}, inplace = True)    # filled the null calories values with 130.

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  169 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 5.4 KB

# %%
# replacing using Mean, Median and Mode 

mean_df = pd.read_csv('data.csv')

mean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 5.4 KB

# %%
mean_x = mean_df['Calories'].mean()

mean_df.fillna({'Calories': mean_x}, inplace = True)        #replaced the null calories column with the mean of it.

mean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  169 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 5.4 KB

# %%
df = pd.read_csv('data.csv')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 5.4 KB

# %%
mode_x = df['Calories'].mode()[0]       # accesses the first element of the mode series

mode_x

df.fillna({'Calories': mode_x}, inplace = True)

df.info()

# %%
# fixing wrong data 

import pandas as pd 

df = pd.read_csv('date_data.csv')

df.head()
# Out:
#    Duration            Date  Pulse  Maxpulse    Calories
# 0        60    '2020/12/01'    110       130       409.1
# 1        60    '2020/12/02'    117       145       479.0
# 2        60    '2020/12/03'    103       135       340.0
# 3        45    '2020/12/04'    109       175       282.4
# 4       450    '2020/12/05'    117       148       406.0

# %%
# replacing values 

df.loc[4, 'Duration'] = 45      # replaced the duration 450 with 45

df.head(10)
# Out:
#    Duration            Date  Pulse  Maxpulse    Calories
# 0        60    '2020/12/01'    110       130       409.1
# 1        60    '2020/12/02'    117       145       479.0
# 2        60    '2020/12/03'    103       135       340.0
# 3        45    '2020/12/04'    109       175       282.4
# 4        45    '2020/12/05'    117       148       406.0
# 5        60    '2020/12/06'    102       127       300.0
# 6        60    '2020/12/07'    110       136       374.0
# 7        50    '2020/12/08'    104       134       253.3
# 8        30    '2020/12/09'    109       133       195.1
# 9        60    '2020/12/10'     98       124       269.0

# %%
# removing rows 

for x in df.index:
    if df.loc[x, 'Duration'] > 120:
        df.drop(x, inplace= True)

# %%
# removing duplicates 

df.duplicated()     #returns true for duplicated row else false
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12     True
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# dtype: bool

# %%
df.drop_duplicates(inplace= True)   # here inplace is used so that it doesnot return the new dataframe but removes all the duplicates

# %%
# checking the existence of duplicates 

df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# dtype: bool

# %%
# data correlations 

data_df = pd.read_csv('data.csv')

# %%
# calculates the relationship between the columns of the dataset
# also 'corr' ignores the non-numeric columns.

data_df.corr()

# number varies between -1 and 1
# Out:
#           Duration     Pulse  Maxpulse  Calories
# Duration  1.000000 -0.155408  0.009403  0.922717
# Pulse    -0.155408  1.000000  0.786535  0.025121
# Maxpulse  0.009403  0.786535  1.000000  0.203813
# Calories  0.922717  0.025121  0.203813  1.000000

# %%
# pandas plotting

import matplotlib.pyplot as plt 

data_df.plot(kind= 'scatter', x='Duration', y='Calories')

plt.show()      # result: higher the duration, higher the calories burnt.

# %%
data_df.plot(kind='scatter', x='Duration', y='Maxpulse')

plt.show()      # result: there is no relation between the duration and maxpulse

# %%
# histogram: shows the frequency of each interval 

data_df['Duration'].plot(kind='hist')

# result: there were over 100 workouts that lasted between 50 and 60 minutes.
# Out:
# <Axes: ylabel='Frequency'>
